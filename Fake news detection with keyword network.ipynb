# %% [markdown]
# ---

# %%
import pandas as pd
import numpy as np
import torch
import os
import random

# %%
class config:
    seed = 42

# %%
def seed_everything(seed: int = 42):
    random.seed(seed)
    np.random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # type: ignore
    torch.backends.cudnn.deterministic = True  # type: ignore
    torch.backends.cudnn.benchmark = True  # type: ignore

# %%
seed_everything(config.seed)

# %% [markdown]
# # 1. Data Description
# - id : claim id
# - label : 0(normal) / 1(fake)
# - published_date : 보도 날짜
# - keybert_keywords : kebert를 통해 추출한 기사 키워드
# - ner_keywords : ner를 통해 추출한 기사 키워드
# - youtube0 ~ youtube9 : 해당 키워드로 유트브에 검색했을 때 나오는 상위 10개의 유투브의 제목, 설명 텍스트

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
submission = pd.read_csv('sample_submission.csv')

# %%
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
device
# Out:
# device(type='cuda', index=0)

# %%
# train data: 3868개의 기사로 구성
train
# Out:
#         id  label                                              claim  \
# 0        0      0  Did a Vermont Woman Post a Joke About Trump Br...
# 1        1      1  Were Baseball Players Photographed Kneeling to...
# 2        2      0  Wisconsin state Rep. John Nygren hits pay dirt...
# 3        3      0  Progressive group accuses Senate splinter grou...
# 4        4      0  Seal with Unusual Stripe Pattern Markings Spot...
# ...    ...    ...                                                ...
# 5272  5272      0  Does Hillary Clinton want a $15 or $12 minimum...
# 5273  5273      1  George Soros s son isn t married to Adam Schif...
# 5274  5274      0  Sanders: It's not impossible to get enough del...
# 5275  5275      1         Donald Trump Pledged to Rename New Mexico?
# 5276  5276      1  Was a Japanese Man Crushed to Death by a Pile ...
#
#      published_date                     keybert_keywords  \
# 0        2018-01-25        ['trump', 'vermont', 'woman']
# 1        2017-11-08       ['lynchings', 'baseball', 's']
# 2        2019-02-07         ['tax', 'wisconsin', 'dirt']
# 3        2017-11-04      ['donors', 'cashing', 'senate']
# 4        2016-10-21   ['seal', 'washington', 'markings']
# ...             ...                                  ...
# 5272     2016-04-14               ['hillary', 'clinton']
# 5273     2019-10-10         ['sister', 'married', 'son']
# 5274     2016-05-01      ['win', 'sanders', 'delegates']
# 5275     2016-02-29        ['trump', 'mexico', 'donald']
# 5276     2017-03-06  ['pornography', 'death', 'crushed']
#
#                                    ner_keywords  \
# 0                 ['vermont', 'trump', 'woman']
# 1                ['lynchings', 'baseball', 's']
# 2      ['rep', 'wisconsin', 'tax', 'wisconsin']
# 3               ['cashing', 'senate', 'donors']
# 4            ['seal', 'washington', 'markings']
# ...                                         ...
# 5272  ['hillary clinton', 'hillary', 'clinton']
# 5273               ['sister', 'married', 'son']
# 5274            ['delegates', 'win', 'sanders']
# 5275              ['donald', 'mexico', 'trump']
# 5276        ['pornography', 'death', 'crushed']
#
#                                                youtube0  \
# 0     Citizen Trump  A talk given at the University ...
# 1     Tony Shalhoub Still ;Monk ; after all these ye...
# 2     Pocan Shutdown Waste of Time Energy  Pocan Shu...
# 3     Roy Moore s Attorney Refers To News Anchor ;s ...
# 1
# 2     Rep Sean Duffy introduces the Reciprocal Trade...
# 3
# 4
# ...                                                 ...
# 5272  Hillary Clinton ;s entire Pennsylvania primary...
# 5273  Sheikh Mohammed bin Rashid ;s daugher Maryam m...
# 5274  Bernie Sanders Determined to Fight for Every D...
# 5275  Enrique Peña Nieto Mexico will not pay for Don...
# 5276
#
#                                                youtube7  \
# 0     AM Executive Session Gender Matters The U S Pr...
# 1
# 2     Rep Dan Caulkins on IL Minimum Wage Hike  Stat...
# 3
# 4
# ...                                                 ...
# 5272  Hillary Clinton on NY Primary Win FULL SPEECH ...
# 5273  Amelia and Link Tell Meredith About the Baby G...
# 5274  I ;m In It to Win It Bernie Sanders  If you wa...
# 5275  Video Donald Trump supporter tells protestor q...
# 5276
#
#                                                youtube8  \
# 0     Trump Discusses Tax Bill Gives ;Total Support ...
# 1
# 2     Rep Weber Worried More Jobs Will Leave IL  Rea...
# 3
# 4
# ...                                                 ...
# 5272  Thank you New York Hillary Clinton  In her New...
# 5273  Tamron Hall Talks with Her Nephew About the Mu...
# 5274  Bernie Sanders Delegate Reacts to New York Pri...
# 5275  Mexico accuses Donald Trump of sounding like a...
# 5276
#
#                                                youtube9
# 0     Chicago s Women s March January  This is what ...
# 1
# 2     Foxconn May Not Build B Wisconsin Plant Presid...
# 3
# 4
# ...                                                 ...
# 5272  Hillary Clinton ;s full New York primary victo...
# 5273  Thomas Doherty Juliet Doherty amp; Harry Jarvi...
# 5274  Bernie Sanders Celebrates West Virginia Win NB...
# 5275  KIDS REACT TO DONALD TRUMP  Kids sit down and ...
# 5276
#
# [5277 rows x 16 columns]

# %%
# test data: 1856개의 기사로 구성 (test에는 라벨값이 없으므로, 이를 예측하여 submission 해야 함.)
test
# Out:
#         id                                              claim published_date  \
# 0        0  According to the CDC so far this year Florida ...     2020-05-27
# 1        1  Claim that Rep. Alexandria Ocasio-Cortez tweet...     2020-06-23
# 2        2  Models projecting COVID-19 deaths are talking ...     2020-05-05
# 3        3  A video has been viewed tens of thousands of t...     2020-05-02
# 4        4  A video shows how Indian police frightened tho...     2020-04-24
# ...    ...                                                ...            ...
# 1851  1851  COMMENTARY: COVID-19 Diary Day 6: Clinicians' ...     2020-04-10
# 1852  1852  Facebook and Instagram posts shared thousands ...     2020-05-25
# 1853  1853  Could an antiparasitic drug kill off SARS-CoV-...     2020-04-21
# 1854  1854  A video has been have been viewed thousands of...     2020-04-03
# 1855  1855  A WhatsApp message circulating in South Sudan ...     2020-04-06
#
#                            keybert_keywords  \
# 0                             ['pneumonia']
# 1      ['november', 'elections', 'tweeted']
# 2                  ['deaths', 'mitigation']
# 3          ['instagram', 'facebook', 'tea']
# 4     ['ambulance', 'police', 'frightened']
# ...                                     ...
# 1851                ['clinicians', 'diary']
# 1852  ['instagram', 'facebook', 'vaccines']
# 1853      ['antiparasitic', 'drug', 'kill']
# 1854     ['facebook', 'covid', 'sanitiser']
# 1855              ['sudan', 'son', 'covid']
#
#                                   ner_keywords  \
# 0              ['florida', 'pneumonia', 'cdc']
# 1                       ['covid', 'us', 'rep']
# 2            ['deaths', 'covid', 'mitigation']
# 3             ['covid', 'uk', 'boris johnson']
# 4             ['covid', 'indian', 'ambulance']
# ...                                        ...
# 1851                   ['clinicians', 'diary']
# 1852     ['instagram', 'facebook', 'vaccines']
# 1853         ['sars', 'antiparasitic', 'drug']
# 1854        ['covid', 'facebook', 'sanitiser']
# 1855  ['south sudan', 'covid', 'sudan', 'son']
#
#                                                youtube0  \
# 0     Watch Full Coronavirus Coverage May NBC News N...
# 1     Maps show explosive growth of coronavirus in U...
# 2     President Donald Trump downplays models projec...
# 3     Coronavirus Boris Johnson updates nation on Co...
# 4     Watch TN Police put lockdown violators in ambu...
# ...                                                 ...
# 1851                     Adding Services and Products
# 1852  Ousted vaccine chief testifies Americans deser...
# 1853  Truth about the corona curing drug Ivermectin ...
# 1854  Students produce hand sanitizer to fight COVID...
# 1855  Coronavirus South Sudan reports first case fir...
#
#                                                youtube1  \
# 0     Watch Full Coronavirus Coverage May NBC News N...
# 1     Rep Raja Krishnamoorthi on Continued Fallout o...
# 2     Trump keeps predicting coronavirus death tolls...
# 3     Coronavirus How Boris Johnson government ;s po...
# 4     Fake Covid patient TN Police releases awarenes...
# ...                                                 ...
# 1851                                Adding Clinicians
# 1852  Anti Vaxxers Could Pose Public Health Risk Whe...
# 1853  Zinc Ascorbic Acid Steroids Fluids and Ivermec...
# 1854  How to Draw a Bottle of Hand Sanitizer Cartoon...
# 1855  COVID Numbers and Trends around the globe  Ken...
#
#                                                youtube2  \
# 0     Ask the expert Here ;s why screening is a good...
# 1     Biologist says young people are fueling Covid ...
# 2     Trump Claims New Estimate Predicting More Coro...
# 3     Boris Johnson unveils new COVID lockdown rules...
# 4     TN Police ;Prank ; Lockdown Violators With Fak...
# ...                                                 ...
# 1851                 Acting Director ;s Message April
# 1852  Hope in Thailand for a ;cheaper ; coronavirus ...
# 1853  Intro to Viruses Antivirals and Vaccines Dr Pa...
# 1854  I Can ;t Get No Sanitiser A Covid Parody Famil...
# 1855  LIVING IN SUDAN what it ;s really like vlog ال...
#
#                                                youtube3  \
# 0     MORE Questions for an Infectious Disease Speci...
# 1     Former Allergan CEO on the most likely timelin...
# 2     Is COVID Seasonal  View CME information and cl...
# 3     Coronavirus Public challenge Boris Johnson ;s ...
# 4     Police drone catches teens violating COVID loc...
# ...                                                 ...
# 1851                 Adding and Editing Account Users
# 1852  Coronavirus crisis These four COVID vaccines a...
# 1853  Cellular Mechanism of Action of Ivermectin Ant...
# 1854  Soap vs Hand Sanitizer Which is best for preve...
# 1855  Libyan rebel leader who led Gaddafi overthrow ...
#
#                                                youtube4  \
# 0                                Coronavirus and Cuba
# 1     Rep DeGette questions top U S health officials...
# 2     The Bubonic Plague and COVID – Two Diseases in...
# 3     Coronavirus UK now ;past the peak ; says Boris...
# 4     India s mobile coronavirus testing van hits Ne...
# ...                                                 ...
# 1851  Advice for New Therapists  Subscribe now for m...
# 1852  How Our Lifestyle is Going To Be Transformed A...
# 1853  EYE PARASITES HOW TO KILL A PARASITE IN THE EY...
# 1854  Inside a Dubai hand sanitiser factory  With th...
# 1855            South Sudanese comedy on corona virus
#
#                                                youtube5  \
# 0     Understanding and Managing Coronavirus in SNF ...
# 1     Rep Kevin McCarthy on Covid spikes reopening t...
# 2     Coronavirus outbreak B C reports new cases add...
# 3     UK PM Boris Johnson returns to work after reco...
# 4     Ambulance Traffic Jams At Moscow Hospitals As ...
# ...                                                 ...
# 1851                           COVID Clinical Webinar
# 1852  How do vaccines work and what are their variou...
# 1853  Ringworm Tinea Corporis Causes Risk Factors Si...
# 1854  Coronavirus Hand sanitiser vs soap which prote...
# 1855  Discussion on Challenges and Strategies for M ...
#
#                                                youtube6  \
# 0     SARS CoV Pandemic Caltech Seminar Day Online S...
# 1     Rep Kevin Brady on back to work bonus proposal...
# 2     Coronavirus Number of UK deaths decline from p...
# 3     Boris Johnson We are past the peak of disease ...
# 4     ;India ;s Covid recovery rate ; Union govt on ...
# ...                                                 ...
# 1851  Diary of a Researcher Day  April Libby Researc...
# 1852  CEO Pascal Soriot on COVID vaccine CNN  AstraZ...
# 1853  COVID UPDATE HYDROXYCHLOROQUINE WHEN amp; HOW ...
# 1854  India Patna installs full body sanitiser tunne...
# 1855  Coronavirus Symptoms exposure to COVID with Pr...
#
#                                                youtube7  \
# 0     CAH Swingbed Initiative with Kerry Dunning  Ke...
# 1     Florida and Texas struggle with surging corona...
# 2     Coronavirus model projects deaths in U S to ne...
# 3     In full Boris Johnson says he won ;t lift UK c...
# 4     Police drone interrupts couple ;s romantic get...
# ...                                                 ...
# 1851  THE HARDEST SURGERY OPERATION I ;VE EVER EXPER...
# 1852  The Market for Emergency Vaccines Is Like No O...
# 1853  Could Ivermectin Help Fight COVID  Ivermectin ...
# 1854  Coronavirus; Old KSRTC Bus Turned Into Mobile ...
# 1855  Coronavirus les enfants réfugiés en danger l ;...
#
#                                                youtube8  \
# 0     Diabetics and Novel Coronavirus  ▻ Theresa De ...
# 1     What flying in the U S amid the coronavirus pa...
# 2     Modeling COVID Transmission and Containment in...
# 3     Boris Johnson s new stay alert message splits ...
# 4     Watch Tamil Nadu Police put lockdown violators...
# ...                                                 ...
# 1851                      Configuring Business Basics
# 1852  CR FOR VACCINE DEVELOPMENT STATUS OF ALL VACCI...
# 1853  La ivermectina ¿Ocurrencia o creencia para tra...
# 1854  Coronavirus Hand sanitiser accidental poisonin...
# 1855  NBG update the citizens how to protect themsel...
#
#                                                youtube9
# 0     CDPHE explains how it classifies COVID deaths ...
# 1     U S Virus Surge Ample Opportunity for Covid to...
# 2     UK records most Covid deaths in Europe but Raa...
# 3     Watch Back Boris Johnson Addresses UK On State...
# 4     Pak Reaction on Indian Police Prank Offenders ...
# ...                                                 ...
# 1851                          Quick Navigational Tips
# 1852  Trials show progress on Covid immunity vaccine...
# 1853  FDA approved drug Ivermectin inhibits replicat...
# 1854  COVID APMC vegetable market in Navi Mumbai set...
# 1855  Online Event Unpacking the Covid Crisis in Afr...
#
# [1856 rows x 15 columns]

# %%
# test 데이터 내 1856개의 노드에 대해 예측된 라벨 (sample에서는 모두 0으로 초기화되어 있음.)
submission
# Out:
#         id  label
# 0        0      0
# 1        1      0
# 2        2      0
# 3        3      0
# 4        4      0
# ...    ...    ...
# 1851  1851      0
# 1852  1852      0
# 1853  1853      0
# 1854  1854      0
# 1855  1855      0
#
# [1856 rows x 2 columns]

# %% [markdown]
# # 2. Graph Example

# %%
# install dgl
# https://www.dgl.ai/pages/start.html

# !pip install -q dgl-cu113 dglgo -f https://data.dgl.ai/wheels/repo.html
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.2/239.2 MB 5.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.5/63.5 kB 3.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.2/45.2 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.4/52.4 kB 6.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 109.6/109.6 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.8/78.8 kB 9.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 51.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 5.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 95.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 485.6/485.6 kB 48.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 572.7/572.7 kB 53.7 MB/s eta 0:00:00
#   Building wheel for littleutils (setup.py) ... done

# %%
import numpy as np
from scipy.sparse import coo_matrix
import torch
import dgl
# Out:
# DGL backend not selected or invalid.  Assuming PyTorch for now.
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)

# %%
train.head(20)
# Out:
#     id  label                                              claim  \
# 0    0      0  Did a Vermont Woman Post a Joke About Trump Br...
# 1    1      1  Were Baseball Players Photographed Kneeling to...
# 2    2      0  Wisconsin state Rep. John Nygren hits pay dirt...
# 3    3      0  Progressive group accuses Senate splinter grou...
# 4    4      0  Seal with Unusual Stripe Pattern Markings Spot...
# 5    5      1  Donald Trump Protester Speaks Out I Was Paid 3...
# 6    6      1  Are Thieves Stealing License Plates in a Carja...
# 7    7      1  Did MSNBC Reporter Say I Hope Coronavirus Kill...
# 8    8      0   Rep. Tom Cole: Half of Oklahoma homes have a gun
# 9    9      1  A claim has circulated on social media that a ...
# 10  10      1  Rainbow shimmers behind a COVID-19 disinfectan...
# 11  11      0  Hillary Clinton: Cleveland has higher rates of...
# 12  12      1  Did a Federal Judge Nullify PA Election Result...
# 13  13      0  Hillary Clinton says Donald Trump has said he ...
# 14  14      0  Did Senate candidate Leah Vukmir seek 'lenienc...
# 15  15      0  Debt payments for Wisconsin road work have dou...
# 16  16      0                   European Parental Leave Benefits
# 17  17      1  Did a Man Sue Dyson After Being Partially Emas...
# 18  18      1  Does a Photograph Show a Dementor Like Figure ...
# 19  19      0  Greg Abbott says if Texas were a country, its ...
#
#    published_date                       keybert_keywords  \
# 0      2018-01-25          ['trump', 'vermont', 'woman']
# 1      2017-11-08         ['lynchings', 'baseball', 's']
# 2      2019-02-07           ['tax', 'wisconsin', 'dirt']
# 3      2017-11-04        ['donors', 'cashing', 'senate']
# 4      2016-10-21     ['seal', 'washington', 'markings']
# 5      2016-06-06          ['trump', 'rally', 'protest']
# 6      2016-12-22  ['carjacking', 'thieves', 'stealing']
# 7      2020-03-16            ['covid', 'msnbc', 'kills']
# 8      2018-03-01             ['gun', 'oklahoma', 'tom']
# 9      2020-03-24       ['covid', 'hantavirus', 'virus']
# 10     2020-02-20     ['china', 'truck', 'disinfectant']
# 11     2016-03-06  ['cleveland', 'hillary', 'poisoning']
# 12     2018-03-14         ['fraud', 'voter', 'election']
# 13     2016-09-25        ['trump', 'hillary', 'clinton']
# 14     2018-07-17    ['lawmaker', 'convicted', 'senate']
# 15     2018-06-10   ['wisconsin', 'democrat', 'doubled']
# 16     2017-03-16   ['european', 'parental', 'benefits']
# 17     2018-12-06   ['vacuum', 'cleaner', 'emasculated']
# 18     2017-03-06        ['photograph', 'sky', 'figure']
# 19     2016-09-14             ['th', 'texas', 'economy']
#
#                                         ner_keywords  \
# 0                      ['vermont', 'trump', 'woman']
# 1                     ['lynchings', 'baseball', 's']
# 2           ['rep', 'wisconsin', 'tax', 'wisconsin']
# 3                    ['cashing', 'senate', 'donors']
# 4                 ['seal', 'washington', 'markings']
# 5                      ['rally', 'protest', 'trump']
# 6              ['carjacking', 'thieves', 'stealing']
# 7               ['covid', 'trump', 'covid', 'msnbc']
# 8                         ['rep', 'gun', 'oklahoma']
# 9          ['covid', 'china', 'covid', 'hantavirus']
# 10              ['covid', 'china', 'china', 'truck']
# 11       ['hillary clinton', 'cleveland', 'hillary']
# 12                    ['fraud', 'voter', 'election']
# 13  ['hillary clinton', 'trump', 'trump', 'hillary']
# 14               ['lawmaker', 'convicted', 'senate']
# 15         ['democrat', 'wisconsin', 'scott walker']
# 16              ['european', 'parental', 'benefits']
# 17              ['vacuum', 'cleaner', 'emasculated']
# 18                   ['photograph', 'sky', 'figure']
# 19           ['texas', 'greg abbott', 'th', 'texas']
#
#                                              youtube0  \
# 0   Citizen Trump  A talk given at the University ...
# 1   Tony Shalhoub Still ;Monk ; after all these ye...
# 2   Pocan Shutdown Waste of Time Energy  Pocan Shu...
# 3   Roy Moore s Attorney Refers To News Anchor ;s ...
# 4   Parking Lot Striping Garland Texas  Asphalt st...
# 5   Protesters Interrupt Trump Rally in Albuquerqu...
# 6   Arrested In Intricate Torrance Car Theft Ring ...
# 7   Tracking President Trump ;s Response To COVID ...
# 8   Tulsa Project General Meeting March th  Tulsa ...
# 9   After Coronavirus Hantavirus Wreaks Havoc In C...
# 10  China disinfects entire cities to fight corona...
# 11             HILLARY CLINTON GIVES VICTORY SPEECH
# 12  Texas AG to prosecute three Robstown residents...
# 13  Donald Trump vs Hillary Clinton Debate Cold Op...
# 14  Ex New York senator and son convicted of bribe...
# 15  Democrats Win HUGE In Wisconsin Scott Walker S...
# 16  Engaging Native Families and Communities A Too...
# 17  Boston Man Did NOT Sue Dyson for Million NOT P...
# 18  Portraits of a planet Earth from space  For ce...
# 19  Governor Abbott Discusses The Texas Economy Wi...
#
#                                              youtube1  \
# 0   News Donald Trump has a great woman problem  N...
# 1   Lesson Class differences and racial variation ...
# 2   Lawmaker This couldn ;t be more embarrassing f...
# 3   Documents that Changed the Way We Live  Docume...
# 4   Learn about the MAHLE Original Gasket Line  Bi...
# 5   Protests outside Trump Rally in Tampa mostly p...
# 6   Spider Man Movie Uncle Ben ;s Death Scene Movi...
# 7   The Cult Of Trump During Coronavirus All In MS...
# 8   Rep Tim Ryan We Need A Firmer Position On Guns...
# 9   Hantavirus China Here s Why Hantavirus Isn ;t ...
# 10  Covid Disinfectant tunnel in China sprays work...
# 11  Hillary Clinton delivers speech in Cleveland O...
# 2   Rep Weber Worried More Jobs Will Leave IL  Rea...
# 3
# 4
# 5   Donald Trump Protests at Anaheim Convention Ce...
# 6            GTA Vice City Car Jacking  GTA vice city
# 7   U S Ill Served By Trump ;s Repeated Lying Abou...
# 8   Tennessee Capitol Report February  This episod...
# 9   Hantavirus after coronavirus in China More Fat...
# 10  Ethiopia says its students well taken care of ...
# 11  Hillary Clinton On Nancy Reagan She Had A Lot ...
# 12  Donald Trump slams recount efforts claims vote...
# 13  Will you accept the outcome of the election Cl...
# 14  Senator Rob Portman ;Of Course We Should Talk ...
# 15  Poll Walker Trump approval ratings climb sligh...
# 16  GOP Wants to Take Away Your Healthcare amp; Ma...
# 17
# 18  Render Like a Photographer  Back by popular de...
# 19  Freight Movement Redefined  Texas Governor Gre...
#
#                                              youtube9
# 0   Chicago s Women s March January  This is what ...
# 1
# 2   Foxconn May Not Build B Wisconsin Plant Presid...
# 3
# 4
# 5   Dallas police hold crowd management training i...
# 6   Public Safety Concerns  A public safety survey...
# 7   Chris Hayes On Trump s Failing Response To Cor...
# 8   There Ought To Be A Law Overcriminalization  R...
# 9   After Coronavirus Hantavirus Wreaks In China T...
# 10  Aamir Khan Indian Bollywood megastar sends mes...
# 11  Hillary Clinton speaks about jobs and the econ...
# 12  Italy ;Complicated ; ;uncertain ; ;shameful ; ...
# 13  Donald Trump vs Hillary Clinton All Debate Int...
# 14  Senator Blumenthal Congress Can Go On The Offe...
# 15  Gronik For Wisconsin Inc Radio Ad quot;It s Ti...
# 16  Part H E Thiedemann Ambassador  NCRE seminar s...
# 17
# 18  Best iPhone Photography Apps  Talking about my...
# 19  Refugee Resettlement Providers Press Conferenc...

# %%
total = pd.concat([train,test])

# %%
total = total.reset_index(drop=True)

# %%
total['claim'][0]
# Out:
# 'Did a Vermont Woman Post a Joke About Trump Bringing Back Slavery ?'

# %%
youtube_pool = []
for idx in range(len(total)):
  for i in range(10):
    col_name = 'youtube'+str(i)
    if len(total[col_name][idx])!=1:
      youtube_pool.append(total[col_name][idx])
len(youtube_pool)
# Out:
# 68256

# %%
len(set(youtube_pool)) #겹치는 비디오 존재
# Out:
# 59875

# %%
video_list = list(set(youtube_pool))

# %%
follow_dst = [] #news
follow_src = [] #video
for idx in range(len(total)):
  for i in range(10):
    col_name = 'youtube'+str(i)
    if len(total[col_name][idx])!=1:
      follow_dst.append(idx)
      follow_src.append(video_list.index(total[col_name][idx]))

# %%
len(follow_src), len(follow_dst)
# Out:
# (68256, 68256)

# %%
for row in range(len(total)):
  total['ner_keywords'][row] = total['ner_keywords'][row].replace("[","").replace("]","").replace("'","").replace(" ","").split(",")
# Out:
# <ipython-input-21-ee0b77986c82>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   total['ner_keywords'][row] = total['ner_keywords'][row].replace("[","").replace("]","").replace("'","").replace(" ","").split(",")

# %%
share_src = []
share_dst = []
for i, i_keywords in enumerate(total['ner_keywords']):
  for j, j_keywords in enumerate(total['ner_keywords']):
    intersection = list(set(i_keywords)&set(j_keywords))
    if len(intersection)!=0:
      share_src.append(i)
      share_dst.append(j)

# %%
len(share_src), len(share_dst)
# Out:
# (3319317, 3319317)

# %%
ew = []
for i, i_keywords in enumerate(total['ner_keywords']):
  for j, j_keywords in enumerate(total['ner_keywords']):
    intersection = list(set(i_keywords)&set(j_keywords))
    if len(intersection)>=3:
      ew.append(3)
    elif len(intersection)==2:
      ew.append(2)
    elif len(intersection)==1:
      ew.append(1)
len(ew)
# Out:
# 3319317

# %%
hetero_graph = dgl.heterograph({
    ('video', 'follow', 'news'): (follow_src,follow_dst), 
    ('news', 'followed_by', 'video'): (follow_dst,follow_src),
    ('news', 'share_keyword_with', 'news'): (share_src, share_dst)
    })

# %%
hetero_graph = hetero_graph.to(device)

# %%
hetero_graph
# Out:
# Graph(num_nodes={'news': 7133, 'video': 59875},
#       num_edges={('news', 'followed_by', 'video'): 68256, ('news', 'share_keyword_with', 'news'): 3319317, ('video', 'follow', 'news'): 68256},
#       metagraph=[('news', 'video', 'followed_by'), ('news', 'news', 'share_keyword_with'), ('video', 'news', 'follow')])

# %%
pip install sentence-transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting transformers<5.0.0,>=4.6.0 (from sentence-transformers)
#   Downloading transformers-4.29.2-py3-none-any.whl (7.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 71.6 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (2.0.1+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (0.15.2+cu118)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (from sentence-transformers) (3.8.1)
# Collecting sentencepiece (from sentence-transformers)
#   Downloading sentencepiece-0.1.99-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 80.7 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0 (from sentence-transformers)
#   Downloading huggingface_hub-0.14.1-py3-none-any.whl (224 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 30.6 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (3.12.0)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2023.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (2.27.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers) (23.1)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6.0->sentence-transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence-transformers) (16.0.5)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1 (from transformers<5.0.0,>=4.6.0->sentence-transformers)
#   Downloading tokenizers-0.13.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 109.6 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (8.1.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk->sentence-transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.10/dist-packages (from torchvision->sentence-transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6.0->sentence-transformers) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6.0->sentence-transformers) (1.3.0)
# Building wheels for collected packages: sentence-transformers
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125926 sha256=bd1a1a0d654ae3815ca97bf4f1c0b4b8fc73d98c7da8796d6c0a6f8120b708db
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence-transformers
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, sentence-transformers
# Successfully installed huggingface-hub-0.14.1 sentence-transformers-2.2.2 sentencepiece-0.1.99 tokenizers-0.13.3 transformers-4.29.2

# %%
import numpy as np
import torch
from sentence_transformers import SentenceTransformer, models

news_sentences = total['claim'].tolist()

se_model = SentenceTransformer('Pavankalyan/Sentence_embedding_fine-tuned')

news_embeddings = se_model.encode(news_sentences)
video_embeddings = se_model.encode(video_list)
# Out:
# Downloading (…)b926c/.gitattributes:   0%|          | 0.00/1.44k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7938bb926c/README.md:   0%|          | 0.00/3.49k [00:00<?, ?B/s]
# Downloading (…)38bb926c/config.json:   0%|          | 0.00/658 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/125 [00:00<?, ?B/s]
# Downloading (…)b926c/tokenizer.json:   0%|          | 0.00/712k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/348 [00:00<?, ?B/s]
# Downloading (…)7938bb926c/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)8bb926c/modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]

# %%
news_embeddings.shape, video_embeddings.shape
# Out:
# ((7133, 768), (59875, 768))

# %%
hetero_graph.nodes['news'].data['feature'] = torch.FloatTensor(news_embeddings).to(device)
hetero_graph.nodes['video'].data['feature'] = torch.FloatTensor(video_embeddings).to(device)

# %%
total['label'] = total['label'].fillna(0)
hetero_graph.nodes['news'].data['label'] = torch.LongTensor(total['label'].tolist()).to(device)

# %%
#Adding weight features
hetero_graph.edges['share_keyword_with'].data['weight'] = torch.Tensor(ew).to(device)

# %%
randint = np.random.randint(0,len(train),int(0.8*len(train)))

# %%
len(randint)
# Out:
# 4221

# %%
train_mask = []
val_mask = []
test_mask = []
for n in range(len(train)):
  if n in randint:
    train_mask.append(True)
    val_mask.append(False)
    test_mask.append(False)
  else:
    train_mask.append(False)
    val_mask.append(True)
    test_mask.append(False)
for t in range(len(train),len(total)):
  train_mask.append(False)
  val_mask.append(False)
  test_mask.append(True)

# %%
len(train_mask), len(val_mask), len(test_mask)
# Out:
# (7133, 7133, 7133)

# %%
hetero_graph.nodes['news'].data['train_mask'] = torch.BoolTensor(train_mask).to(device)
hetero_graph.nodes['news'].data['val_mask'] = torch.BoolTensor(val_mask).to(device)
hetero_graph.nodes['news'].data['test_mask'] = torch.BoolTensor(test_mask).to(device)

# %%
# Define a Heterograph Conv model
import torch.nn as nn
from dgl.nn import GraphConv, SAGEConv, GATConv, HeteroGraphConv

class RGCN(nn.Module):
    def __init__(self, in_feats, hid_feats, out_feats, rel_names):
        super().__init__()

        self.conv1 = HeteroGraphConv({
            rel: SAGEConv(in_feats, hid_feats,aggregator_type='mean')
            for rel in rel_names}, aggregate='mean')
        
        self.conv2 = HeteroGraphConv({
            rel: SAGEConv(hid_feats, out_feats, aggregator_type='mean')
            for rel in rel_names}, aggregate='mean')

    def forward(self, graph, inputs):
        # inputs are features of nodes
        h = self.conv1(graph, inputs)
        h = {k: F.relu(v) for k, v in h.items()}
        h = self.conv2(graph, h)
        return h

# %%
n_hetero_features = 768
hidden_feats = 64         
num_classes = 2
lr = 0.001
num_epochs = 200

# %%
model = RGCN(n_hetero_features, hidden_feats, num_classes, hetero_graph.etypes).to(device)

# %%
# 학습에 필요한 데이터 할당 (목적: 뉴스 클래스(허위) 분류)
news_feats = hetero_graph.nodes['news'].data['feature']
video_feats = hetero_graph.nodes['video'].data['feature']
labels = hetero_graph.nodes['news'].data['label']
edge_weight = hetero_graph.edges['share_keyword_with'].data['weight']
train_mask = hetero_graph.nodes['news'].data['train_mask']
val_mask = hetero_graph.nodes['news'].data['val_mask']
test_mask = hetero_graph.nodes['news'].data['test_mask']

# %%
hetero_graph.device, news_feats.device, video_feats.device
# Out:
# (device(type='cuda', index=0),
#  device(type='cuda', index=0),
#  device(type='cuda', index=0))

# %%
import torch.nn.functional as F

# %%
node_features = {'news': news_feats, 'video': video_feats}
h_dict = model(hetero_graph, {'news': news_feats, 'video': video_feats})
h_news = h_dict['news']
h_video = h_dict['video']
# Out:
# /usr/local/lib/python3.10/dist-packages/dgl/backend/pytorch/tensor.py:352: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   assert input.numel() == input.storage().size(), "Cannot convert view " \

# %%
#logits = model(hetero_graph, node_features)['news']

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
criterion = nn.CrossEntropyLoss()

for epoch in range(num_epochs):
    model.train()
    # forward propagation by using all nodes and extracting the user embeddings
    logits = model(hetero_graph, node_features)['news']
    
    # compute loss
    train_loss = criterion(logits[train_mask], labels[train_mask])
    if epoch % 10 == 0:
        print(train_loss.item())
        
    # backward propagation
    optimizer.zero_grad()
    train_loss.backward()
    optimizer.step()

    # evaluation
    num_correct = 0
    num_tests = 0
    if epoch % 10 == 0:
      model.eval()
      with torch.no_grad():
        logits = model(hetero_graph, node_features)['news']
        val_loss = criterion(logits[val_mask], labels[val_mask])
        acc = (logits[val_mask].argmax(dim=1) == labels[val_mask]).float().mean().item()
        print( "Epoch {:05d} | Loss {:.4f} | Accuracy {:.4f} ".format(
        epoch, val_loss.item(), acc))
# Out:
# 0.7912108302116394
# Epoch 00000 | Loss 1.1095 | Accuracy 0.5044
# 0.646106481552124
# Epoch 00010 | Loss 0.5972 | Accuracy 0.6961
# 0.5646876692771912
# Epoch 00020 | Loss 0.5690 | Accuracy 0.7049
# 0.511517345905304
# Epoch 00030 | Loss 0.5450 | Accuracy 0.7244
# 0.47302794456481934
# Epoch 00040 | Loss 0.5332 | Accuracy 0.7343
# 0.43584954738616943
# Epoch 00050 | Loss 0.5265 | Accuracy 0.7422
# 0.4001714289188385
# Epoch 00060 | Loss 0.5203 | Accuracy 0.7468
# 0.3650600016117096
# Epoch 00070 | Loss 0.5192 | Accuracy 0.7480
# 0.33039599657058716
# Epoch 00080 | Loss 0.5188 | Accuracy 0.7493
# 0.29660746455192566
# Epoch 00090 | Loss 0.5210 | Accuracy 0.7455
# 0.26406291127204895
# Epoch 00100 | Loss 0.5250 | Accuracy 0.7430
# 0.23326647281646729
# Epoch 00110 | Loss 0.5310 | Accuracy 0.7372
# 0.2048458307981491
# Epoch 00120 | Loss 0.5393 | Accuracy 0.7385
# 0.1792113482952118
# Epoch 00130 | Loss 0.5488 | Accuracy 0.7410
# 0.15643200278282166
# Epoch 00140 | Loss 0.5593 | Accuracy 0.7426
# 0.13648772239685059
# Epoch 00150 | Loss 0.5712 | Accuracy 0.7422
# 0.11911550164222717
# Epoch 00160 | Loss 0.5836 | Accuracy 0.7426
# 0.10416693985462189
# Epoch 00170 | Loss 0.5963 | Accuracy 0.7410
# 0.09133102744817734
# Epoch 00180 | Loss 0.6092 | Accuracy 0.7418
# 0.0803634375333786
# Epoch 00190 | Loss 0.6223 | Accuracy 0.7401

# %%
model.eval()
with torch.no_grad():
    logits = model(hetero_graph, node_features)['news']

# %%
logits[test_mask]
# Out:
# tensor([[ 3.3047,  1.8273],
#         [ 2.4886,  3.2032],
#         [ 2.4301,  2.3945],
#         ...,
#         [ 4.0169,  0.6004],
#         [-0.3452,  7.1576],
#         [ 0.6187,  5.1358]], device='cuda:0')

# %%
len(logits[test_mask])
# Out:
# 1856

# %%
result = logits[test_mask].argmax(dim=1).cpu()

# %%
submission['label'] = result
submission['label'].value_counts()
# Out:
# 0    932
# 1    924
# Name: label, dtype: int64

# %%
submission.to_csv("s20.csv", index=False)
